# %%
import pandas as pd
import numpy as np

# %%
#Read the data into pandas dataframe

# %%
file_path = "Resources/heart.csv"
heart_df = pd.read_csv(file_path)
heart_df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
#Add pateint_id column to the data

# %%
heart_df['patient_id'] = np.arange(len(heart_df))
heart_df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target  patient_id
# 0   2     3       0           0
# 1   0     3       0           1
# 2   0     3       0           2
# 3   1     3       0           3
# 4   3     2       0           4

# %%
#Check whether there are more than 1000 data points or not.

# %%
len(heart_df)
# Out:
# 1025

# %%
#Rearrange the column names of the data

# %%
heart_df = heart_df[['patient_id','age','sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','target']]
heart_df.head()
# Out:
#    patient_id  age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 0           0   52    1   0       125   212    0        1      168      0
# 1           1   53    1   0       140   203    1        0      155      1
# 2           2   70    1   0       145   174    0        1      125      1
# 3           3   61    1   0       148   203    0        1      161      0
# 4           4   62    0   0       138   294    1        1      106      0
#
#    oldpeak  slope  ca  target
# 0      1.0      2   2       0
# 1      3.1      0   0       0
# 2      2.6      0   0       0
# 3      0.0      2   1       0
# 4      1.9      1   3       0

# %%
#creat patient information dataframe

# %%
patient_df = heart_df[['patient_id','age','sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','target']]
patient_df.head()
# Out:
#    patient_id  age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 0           0   52    1   0       125   212    0        1      168      0
# 1           1   53    1   0       140   203    1        0      155      1
# 2           2   70    1   0       145   174    0        1      125      1
# 3           3   61    1   0       148   203    0        1      161      0
# 4           4   62    0   0       138   294    1        1      106      0
#
#    oldpeak  slope  ca  target
# 0      1.0      2   2       0
# 1      3.1      0   0       0
# 2      2.6      0   0       0
# 3      0.0      2   1       0
# 4      1.9      1   3       0

# %%
output_file_path = "Resources/patients.csv"
patient_df.to_csv(output_file_path, index=False)

# %%
#create chest pain type dataframe

# %%
d = {'chest_pain_type':[0,1,2,3]}
cp_df = pd.DataFrame(data=d)
cp_df.head()
# Out:
#    chest_pain_type
# 0                0
# 1                1
# 2                2
# 3                3

# %%
output_file_path = "Resources/chest_pain_types.csv"
cp_df.to_csv(output_file_path, index=False)

# %%
#create resting electrocardiographic results (values 0,1,2) dataframe

# %%
d = {'resting_electrocardiographic_results':[0,1,2]}
restecg_df = pd.DataFrame(data=d)
restecg_df.head()
# Out:
#    resting_electrocardiographic_results
# 0                                     0
# 1                                     1
# 2                                     2

# %%
output_file_path = "Resources/restecg_types.csv"
restecg_df.to_csv(output_file_path, index=False)

# %%
#the slope of the peak exercise ST segment dataframe

# %%
d = {'slope':[0,1,2]}
slope_df = pd.DataFrame(data=d)
slope_df.head()
# Out:
#    slope
# 0      0
# 1      1
# 2      2

# %%
output_file_path = "Resources/slope.csv"
slope_df.to_csv(output_file_path, index=False)

# %%
#create number of major vessels (0-3) colored by flourosopy dataframe

# %%
d = {'vessel_color':[0,1,2,3]}
vessel_color_df = pd.DataFrame(data=d)
vessel_color_df.head()
# Out:
#    vessel_color
# 0             0
# 1             1
# 2             2
# 3             3

# %%
output_file_path = "Resources/vessel_color.csv"
vessel_color_df.to_csv(output_file_path, index=False)
